# %% [markdown]
# <a href="https://colab.research.google.com/github/datatrail-jhu/python_projects/blob/main/Forming_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Data
#
# In this first notebook we will show how to import data into Python
#
# But before we can read in data we will need to attach some packages just like we did in R.
#
# ## Attaching libraries
#
# Whereas in R we used `library()` here we use `import`. When we import the library we also give it a shorthand. In this case, we are importing `pandas` but for short we'll call this `pd` in the code.

# %%
import pandas as pd

# %% [markdown]
# Now we can read in our csv file. In this example, we will read in a dataset about the most subscribed youtube channels from 2023. We got this dataset from [Kaggle](https://www.kaggle.com/datasets/surajjha101/top-youtube-channels-data/).

# %%
# Read the CSV file
youtube_data = pd.read_csv("/content/data/most_subscribed_youtube_channels.csv")

# %% [markdown]
# Now go to the button on the side of the Google Collab menu to the thing that looks like `{x}`. This is akin to our RStudio environment. It shows us what objects we have saved in our current session.
#
# ![](/content/screenshots/variables.png)
#
# ## Handling datasets
#
# In R we had the function called `head()` but you may recall we would have supplied the data object within the parantheses.
#
# For Python, we do this `.head()` syntax instead.

# %%
youtube_data.head()
# Out:
#    rank                    Youtuber  subscribers      video views video count  \
# 0     1                    T-Series  222,000,000  198,459,090,822      17,317
# 1     2              YouTube Movies  154,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848         786
# 3     4                   SET India  139,000,000  125,764,252,686      91,271
# 4     5                       Music  116,000,000                0           0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4               NaN     2013

# %% [markdown]
# Adding some more text
